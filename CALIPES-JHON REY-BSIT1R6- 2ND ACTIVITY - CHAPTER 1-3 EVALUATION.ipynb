# %%
print("Discuss your learnings on Chapter 1  time-frame 8:00 - 30:35. Minimum of 200 characters")

print('Chapter 1 learnings are the following: ')
print('Algorithm- is a step by step that transform the input into output')
print('Data Structures is a way to store and orrganize data in order to facilitate access and modifications')
print('then the 2 differents of data structures foundations are the Interface and Implementation')
print('Interface is each data has an interface, also it represents the set of operations that a data structure supports.')
print('Implementation provides the internal representation of a data structure.')
print('3 Characteristics of a Data Structure')
print('Correctness- data structures implementation should implement correctly')
print('Time Complexity- running time must be as small as possible')
print('Space Complexity- memory usage of data structure operation should be as little as possible')
print('and the Execution time are Worst case, Average case, Best case')
# Out:
# Discuss your learnings on Chapter 1  time-frame 8:00 - 30:35. Minimum of 200 characters
# Chapter 1 learnings are the following:
# Algorithm- is a step by step that transform the input into output
# Data Structures is a way to store and orrganize data in order to facilitate access and modifications
# then the 2 differents of data structures foundations are the Interface and Implementation
# Interface is each data has an interface, also it represents the set of operations that a data structure supports.
# Implementation provides the internal representation of a data structure.
# 3 Characteristics of a Data Structure
# Correctness- data structures implementation should implement correctly
# Time Complexity- running time must be as small as possible
# Space Complexity- memory usage of data structure operation should be as little as possible
# execution time- Worst case, Average case, Best case

# %%
print("Discuss your learnings on Chapter 1  time-frame 35:00-end of 200 characters")

print('Chapter 1 learnings are the following')
print('Algorithm Complexity')
print('must consider the time and space')
print('and the Space Complexity represents the amount of memory space and the variable parts is a space required by variables')
print('Time Complexity- represents the amount of time required by algorithm to run to completion')
print('Then the local environment set-up on how to install python and the pycharm')
# Out:
# Discuss your learnings on Chapter 1  time-frame 35:00-end of 200 characters
# Chapter 1 learnings are the following
# Algorithm Complexity
# must consider the time and space
# and the Space Complexity represents the amount of memory space and the variable parts is a space required by variables
# Time Complexity- represents the amount of time required by algorithm to run to completion
# Then the local environment set-up on how to install python and the pycharm

# %%
print("Discuss your learnings on Chapter 2  time-frame 5:00 - 9:00. Minimum of 200 characters")

print('Chapter 2 learnings is about DATA')
print('I learned about the types of data. In time 5-9mins I also learned about the Derived Data Type')
print('then the different of Basic Operations, the traversing, searching, insertion, deletion.sorting, and Merging  ')
print('and the Basic operations is the data in the data structure processed by certain operations')
print('Traversing is to move from another space')
print('Searching is to find')
print('Insertion is when you insert an item')
print('Deletion is when you remove an item')
print('Sorting is to sort')
print('Merging is to merge an item')
# Out:
# Discuss your learnings on Chapter 2  time-frame 5:00 - 9:00. Minimum of 200 characters
# Chapter 2 learnings is about DATA
# I learned about the types of data. In time 5-9mins I also learned about the Derived Data Type
# then the different of Basic Operations, the traversing, searching, insertion, deletion.sorting, and Merging
# and the Basic operations is the data in the data structure processed by certain operations
# Traversing is to move from another space
# Searching is to find
# Insertion is when you insert an item
# Deletion is when you remove an item
# Sorting is to sort
# Merging is to merge an item

# %%
print("Discuss your learnings on Chapter 3  time-frame 3:00 - 18:00. Minimum of 200 characters")

print('Chapter 3 learnings are the following')
print('Array- is a container')
print('and how to create an array, the format, and the typecode')
print('the typecode are the codes that to define the type of value the arry will hold')
print('then the basic operations that support the array')
print('and on how to use insertion and deletion etc...')
# Out:
# Discuss your learnings on Chapter 3  time-frame 3:00 - 18:00. Minimum of 200 characters
# Chapter 3 learnings are the following
# Array- is a container
# and how to create an array, the format, and the typecode
# the typecode are the codes that to define the type of value the arry will hold
# then the basic operations that support the array
# and on how to use insertion and deletion etc...

# %%
from array import *
Killogram = array('i', [45, 59, 69, 70, 55])
Killogram.insert(6,57)
Killogram.remove(45)
Killogram[1]= (60)
for b in Killogram:
    print(b)
# Out:
# 59
# 60
# 70
# 55
# 57
